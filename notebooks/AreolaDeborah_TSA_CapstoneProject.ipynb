# %% [markdown]
# <a href="https://colab.research.google.com/github/dlhegend/-TS_Academy_Capstone_Project/blob/main/notebooks/AreolaDeborah_TSA_CapstoneProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
Stock_detailsDF = pd.read_csv('/content/NGX_ASI_Index_Price_Data.csv')
Stock_detailsDF.head()
# Out:
#        date  avr_monthly_kiloprice
# 0  2012-Jan                  20.80
# 1  2012-Feb                  20.52
# 2  2012-Mar                  20.92
# 3  2012-Apr                  21.27
# 4  2012-May                  22.41
